# %%
#2021년 12월 월간 top100 데이터 크롤링 후 선호 장르 조사

# %%
import sys
import os

import pandas as pd
import numpy as np 


from selenium import webdriver  
from selenium.webdriver import ActionChains as AC
from bs4 import BeautifulSoup
import chromedriver_autoinstaller
from tqdm import tqdm
from tqdm import tqdm_notebook
import re
from time import sleep
import time

# 워닝 무시
import warnings
warnings.filterwarnings('ignore')

# %%
# 크롬 웹 브라우저 실행
chrome_path = chromedriver_autoinstaller.install()
driver = webdriver.Chrome(chrome_path)
#사이트 주소는 멜론
driver.get("https://www.melon.com/")
time.sleep(2)

# %%
#멜론차트 클릭
driver.find_element_by_css_selector(".menu_bg.menu01").click( )
time.sleep(1)

# %%
#월간차트 클릭
driver.find_element_by_css_selector(".menu_chart.m4").click( )

# %%
# 곡정보 더보기 버튼 클릭
more_info = driver.find_elements_by_css_selector(".btn.button_icons.type03.song_info")
more_info[0].click()
time.sleep(1)

# %%
# 제목 가져오기
overlays1=".song_name"
titles = driver.find_elements_by_css_selector(overlays1)
titles[0].text
# Out:
# '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)'

# %%
# 가수 가져오기
overlays2=".artist_name"
artist = driver.find_element_by_css_selector(overlays2)
artist.text
# Out:
# 'sokodomo'

# %%
# 앨범 정보
overlays3=".list"
album_info = driver.find_element_by_css_selector(overlays3).text.split('\n')
album_info
# Out:
# ['앨범',
#  '쇼미더머니 10 Episode 2',
#  '발매일',
#  '2021.11.13',
#  '장르',
#  '랩/힙합',
#  'FLAC',
#  'Flac 16/24bit']

# %%
# 앨범이름 
overlays3= ".list"
album_info = driver.find_element_by_css_selector(overlays3).text.split('\n')
album = album_info[1]
album
# Out:
# '쇼미더머니 10 Episode 2'

# %%
#장르
overlays3 = ".list"
album_info = driver.find_element_by_css_selector(overlays3).text.split('\n')
Genre = album_info[5]
Genre
# Out:
# '랩/힙합'

# %%
# 좋아요 수
overlays4="d_like_count"
like = driver.find_element_by_id(overlays4)
like.text
# Out:
# '174,637'

# %%
# 뒤로가기
driver.back()

# %%
# 2021년 12월 차트

# %%
#멜론차트 클릭
driver.find_element_by_css_selector(".menu_bg.menu01").click( )
time.sleep(1)

#월간차트 클릭
driver.find_element_by_css_selector(".menu_chart.m4").click( )

dict={}

n=100

for i in tqdm_notebook(range(0,n)):
    
    #곡 정보 더보기
    more_info = driver.find_elements_by_css_selector(".btn.button_icons.type03.song_info")
    more_info[i].click()
    time.sleep(1)
    
    try:
        target_info={}
        
        # 제목 
        overlays=".song_name"
        titles = driver.find_element_by_css_selector(overlays)
        title=titles.text
        
        #가수
        overlays2=".artist_name"
        artists = driver.find_element_by_css_selector(overlays2)
        artist=artists.text
        
        
        # 앨범 정보
        overlays3=".list"
        album= driver.find_element_by_css_selector(overlays3).text.split('\n')
        album_info=album
        
        time.sleep(1)
        
        # 앨범이름 
        overlays3= ".list"
        album_info= driver.find_element_by_css_selector(overlays3).text.split('\n')
        album_name = album_info[1]
        
        #장르
        overlays3 = ".list"
        album_info= driver.find_element_by_css_selector(overlays3).text.split('\n')
        Genre = album_info[5]
        
        # 좋아요 수
        overlays4="d_like_count"
        likes = driver.find_element_by_id(overlays4)
        like=likes.text
        
        target_info['title'] = title
        target_info['artist'] = artist
        target_info['album_name'] = album_name
        target_info['Genre'] = Genre
        target_info['like'] = like
        time.sleep(1)
        
        #dict에 담기
        dict[i] = target_info
        
        #크롤링 성공하면 글 제목 출력
        print(i, title)
        
        #글 하나 크롤링 후 뒤로가기
        driver.back()
      
    #에러처리
    except:
        driver.back()
        time.sleep(1)
        continue
        
        # 중간,중간에 파일로 저장하기
    if i == 30 or i==50 or i==80:
        # 판다스로 만들기
        import pandas as pd
        df = pd.DataFrame.from_dict(dict, 'index')

        # 저장하기
        df.to_csv("melon_2021_12_chart.csv", encoding='utf-8-sig')
        time.sleep(3)

print('수집한 글 갯수: ', len(dict))
dict
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 0 회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)
# 1 리무진 (Feat. MINO) (Prod. GRAY)
# 2 만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)
# 3 불협화음 (Feat. AKMU) (Prod. GRAY)
# 4 Counting Stars (Feat. Beenzino)
# 5 strawberry moon
# 6 ELEVEN
# 7 쉬어 (Feat. MINO) (Prod. GRAY)
# 8 사랑은 늘 도망가
# 9 다정히 내 이름을 부르면
# 10 Wake Up (Prod. 코드 쿤스트)
# 11 신호등
# 12 All I Want for Christmas Is You
# 13 Savage
# 14 STAY
# 15 Santa Tell Me
# 16 눈이 오잖아(Feat.헤이즈)
# 17 네가 없는 밤 (Feat. ASH ISLAND) (Prod. GRAY)
# 18 Next Level
# 19 MBTI (Feat. 쿠기 & 로꼬) (Prod. GRAY)
# 20 너를 생각해
# 21 OHAYO MY NIGHT
# 22 매일 크리스마스 (Everyday Christmas)
# 23 낙하 (with 아이유)
# 24 문득
# 25 바라만 본다
# 26 Butter
# 27 My Universe
# 28 Snowman
# 29 Permission to Dance
# 30 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)
# 31 호우주의 (Feat. 개코, 넉살 (Nucksal)) (Prod. 코드 쿤스트)
# 32 헤픈 우연
# 33 Weekend
# 34 Dynamite
# 35 깐부 (Feat. 염따, ASH ISLAND) (Prod. TOIL)
# 36 Celebrity
# 37 Peaches (Feat. Daniel Caesar & Giveon)
# 38 Bad Habits
# 39 Last Christmas
# 40 크리스마스니까
# 41 밤하늘의 별을(2020)
# 42 라일락
# 43 고백
# 44 그게 더 편할 것 같아 (N번째 연애 X 멜로망스)
# 45 어떻게 이별까지 사랑하겠어, 널 사랑하는 거지
# 46 찰나가 영원이 될 때 (The Eternal Moment)
# 47 사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)
# 48 이제 나만 믿어요
# 49 너와 나의 Memories
# 50 시간을 거슬러 (낮에 뜨는 달 X 케이윌)
# 51 롤린 (Rollin')
# 52 밝게 빛나는 별이 되어 비춰줄게
# 53 추억은 만남보다 이별에 남아
# 54 모든 날, 모든 순간 (Every day, Every Moment)
# 55 내 손을 잡아
# 56 좋아좋아
# 57 비가 오는 날엔 (2021)
# 58 DUMB DUMB
# 59 Dun Dun Dance
# 60 Blueming
# 61 오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)
# 62 Off My Face
# 63 흰눈
# 64 비와 당신
# 65 08베이식 (Feat. 염따, punchnello)
# 66 나 그댈위해 시 한편을 쓰겠어
# 67 Queendom
# 68 SCIENTIST
# 69 멜로디
# 70 취기를 빌려 (취향저격 그녀 X 산들)
# 71 그날에 나는 맘이 편했을까
# 72 TROUBLE (Prod. Slom)
# 73 그대라는 사치
# 74 ASAP
# 75 Reset (Feat. 개코, Kid Milli) (Prod. 코드 쿤스트)
# 76 작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)
# 77 봄날
# 78 다음생이 있다면 당신을 만나서 다시 사랑할래요
# 79 다시 사랑한다면 (김필 Ver.)
# 80 Savage Love (Laxed - Siren Beat) (BTS Remix)
# 81 에잇(Prod.&Feat. SUGA of BTS)
# 82 탕!♡
# 83 잊었니
# 84 Lovesick Girls
# 85 가을 우체국 앞에서
# 86 별빛 같은 나의 사랑아
# 87 하루만 더
# 88 취중고백
# 89 Life Goes On
# 90 첫 눈
# 91 HERO
# 92 METEOR
# 93 끝사랑
# 94 바래 (Feat. 정인) (Prod. TOIL)
# 95 UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)
# 96 잠이 오질 않네요
# 97 오래된 노래
# 98 밤새 서로 미루다
# 99 Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afrojack)
# 수집한 글 갯수:  100
# {0: {'title': '회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)',
#   'artist': 'sokodomo',
#   'album_name': '쇼미더머니 10 Episode 2',
#   'Genre': '랩/힙합',
#   'like': '175,093'},
#  1: {'title': '리무진 (Feat. MINO) (Prod. GRAY)',
#   'artist': "BE'O (비오)",
#   'album_name': '쇼미더머니 10 Episode 3',
#   'Genre': '랩/힙합',
#   'like': '153,472'},
#  2: {'title': '만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)',
#   'artist': '베이식 (Basick)',
#   'album_name': '쇼미더머니 10 Episode 3',
#   'Genre': '랩/힙합',
#   'like': '99,407'},
#  3: {'title': '불협화음 (Feat. AKMU) (Prod. GRAY)',
#   'artist': 'Mudd the student',
#   'album_name': '쇼미더머니 10 Semi Final',
#   'Genre': '랩/힙합',
#   'like': '68,537'},
#  4: {'title': 'Counting Stars (Feat. Beenzino)',
#   'artist': "BE'O (비오)",
#   'album_name': 'Counting Stars',
#   'Genre': '랩/힙합',
#   'like': '137,990'},
#  5: {'title': 'strawberry moon',
#   'artist': '아이유',
#   'album_name': 'strawberry moon',
#   'Genre': '록/메탈',
#   'like': '174,809'},
#  6: {'title': 'ELEVEN',
#   'artist': 'IVE (아이브)',
#   'album_name': 'ELEVEN',
#   'Genre': '댄스',
#   'like': '87,906'},
#  7: {'title': '쉬어 (Feat. MINO) (Prod. GRAY)',
#   'artist': '아넌딜라이트(Anandelight)',
#   'album_name': '쇼미더머니 10 Episode 1',
#   'Genre': '랩/힙합',
#   'like': '92,461'},
#  8: {'title': '사랑은 늘 도망가',
#   'artist': '임영웅',
#   'album_name': '신사와 아가씨 OST Part.2',
#   'Genre': '발라드, 국내드라마',
#   'like': '107,793'},
#  9: {'title': '다정히 내 이름을 부르면',
#   'artist': '경서예지',
#   'album_name': '다정히 내 이름을 부르면 (경서예지 x 전건호)',
#   'Genre': '발라드',
#   'like': '101,939'},
#  10: {'title': 'Wake Up (Prod. 코드 쿤스트)',
#   'artist': '개코',
#   'album_name': '쇼미더머니 10 Episode 1',
#   'Genre': '랩/힙합',
#   'like': '74,690'},
#  11: {'title': '신호등',
#   'artist': '이무진',
#   'album_name': '신호등',
#   'Genre': '록/메탈',
#   'like': '252,228'},
#  12: {'title': 'All I Want for Christmas Is You',
#   'artist': 'Mariah Carey',
#   'album_name': 'Merry Christmas (Deluxe Anniversary Edition)',
#   'Genre': 'R&B/Soul',
#   'like': '204,169'},
#  13: {'title': 'Savage',
#   'artist': 'aespa',
#   'album_name': 'Savage - The 1st Mini Album',
#   'Genre': '댄스',
#   'like': '134,854'},
#  14: {'title': 'STAY',
#   'artist': 'The Kid LAROI',
#   'album_name': 'Stay',
#   'Genre': 'POP',
#   'like': '197,757'},
#  15: {'title': 'Santa Tell Me',
#   'artist': 'Ariana Grande',
#   'album_name': 'Santa Tell Me',
#   'Genre': 'POP',
#   'like': '216,160'},
#  16: {'title': '눈이 오잖아(Feat.헤이즈)',
#   'artist': '이무진',
#   'album_name': '눈이 오잖아(Feat.헤이즈)',
#   'Genre': '발라드',
#   'like': '47,674'},
#  17: {'title': '네가 없는 밤 (Feat. ASH ISLAND) (Prod. GRAY)',
#   'artist': "BE'O (비오)",
#   'album_name': '쇼미더머니 10 Final',
#   'Genre': '랩/힙합',
#   'like': '49,227'},
#  18: {'title': 'Next Level',
#   'artist': 'aespa',
#   'album_name': 'Next Level',
#   'Genre': '댄스',
#   'like': '231,647'},
#  19: {'title': 'MBTI (Feat. 쿠기 & 로꼬) (Prod. GRAY)',
#   'artist': "BE'O (비오)",
#   'album_name': '쇼미더머니 10 Semi Final',
#   'Genre': '랩/힙합',
#   'like': '41,915'},
#  20: {'title': '너를 생각해',
#   'artist': '주시크 (Joosiq)',
#   'album_name': '너를 생각해',
#   'Genre': 'R&B/Soul, 인디음악',
#   'like': '89,960'},
#  21: {'title': 'OHAYO MY NIGHT',
#   'artist': '디핵 (D-Hack)',
#   'album_name': 'OHAYO MY NIGHT',
#   'Genre': '랩/힙합',
#   'like': '169,206'},
#  22: {'title': '매일 크리스마스 (Everyday Christmas)',
#   'artist': '다비치',
#   'album_name': '매일 크리스마스 (Everyday Christmas)',
#   'Genre': '댄스',
#   'like': '23,812'},
#  23: {'title': '낙하 (with 아이유)',
#   'artist': 'AKMU (악뮤)',
#   'album_name': 'NEXT EPISODE',
#   'Genre': '록/메탈',
#   'like': '162,197'},
#  24: {'title': '문득',
#   'artist': "BE'O (비오)",
#   'album_name': 'Bipolar',
#   'Genre': '랩/힙합',
#   'like': '72,624'},
#  25: {'title': '바라만 본다',
#   'artist': 'MSG워너비(M.O.M)',
#   'album_name': 'MSG워너비 1집',
#   'Genre': '발라드',
#   'like': '167,502'},
#  26: {'title': 'Butter',
#   'artist': '방탄소년단',
#   'album_name': 'Butter',
#   'Genre': '댄스',
#   'like': '261,800'},
#  27: {'title': 'My Universe',
#   'artist': 'Coldplay',
#   'album_name': 'My Universe',
#   'Genre': 'POP',
#   'like': '144,676'},
#  28: {'title': 'Snowman',
#   'artist': 'Sia',
#   'album_name': 'Everyday Is Christmas (Snowman Deluxe Edition)',
#   'Genre': 'POP',
#   'like': '200,777'},
#  29: {'title': 'Permission to Dance',
#   'artist': '방탄소년단',
#   'album_name': 'Butter / Permission to Dance',
#   'Genre': '댄스',
#   'like': '193,226'},
#  30: {'title': '미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)',
#   'artist': '아이유',
#   'album_name': 'Real',
#   'Genre': '댄스',
#   'like': '166,979'},
#  31: {'title': '호우주의 (Feat. 개코, 넉살 (Nucksal)) (Prod. 코드 쿤스트)',
#   'artist': '조광일',
#   'album_name': '쇼미더머니 10 Semi Final',
#   'Genre': '랩/힙합',
#   'like': '32,994'},
#  32: {'title': '헤픈 우연',
#   'artist': '헤이즈 (Heize)',
#   'album_name': 'HAPPEN',
#   'Genre': 'R&B/Soul',
#   'like': '166,377'},
#  33: {'title': 'Weekend',
#   'artist': '태연 (TAEYEON)',
#   'album_name': 'Weekend',
#   'Genre': '댄스',
#   'like': '156,219'},
#  34: {'title': 'Dynamite',
#   'artist': '방탄소년단',
#   'album_name': 'Dynamite (DayTime Version)',
#   'Genre': '댄스',
#   'like': '428,118'},
#  35: {'title': '깐부 (Feat. 염따, ASH ISLAND) (Prod. TOIL)',
#   'artist': '쿤타',
#   'album_name': '쇼미더머니 10 Episode 3',
#   'Genre': '랩/힙합',
#   'like': '30,833'},
#  36: {'title': 'Celebrity',
#   'artist': '아이유',
#   'album_name': "IU 5th Album 'LILAC'",
#   'Genre': '댄스',
#   'like': '310,368'},
#  37: {'title': 'Peaches (Feat. Daniel Caesar & Giveon)',
#   'artist': 'Justin Bieber',
#   'album_name': 'Justice (The Complete Edition)',
#   'Genre': 'POP',
#   'like': '210,177'},
#  38: {'title': 'Bad Habits',
#   'artist': 'Ed Sheeran',
#   'album_name': '=',
#   'Genre': 'POP',
#   'like': '96,811'},
#  39: {'title': 'Last Christmas',
#   'artist': 'Ariana Grande',
#   'album_name': 'Christmas Kisses',
#   'Genre': 'POP',
#   'like': '43,278'},
#  40: {'title': '크리스마스니까',
#   'artist': '성시경',
#   'album_name': 'Jelly Christmas 2012 HEART PROJECT',
#   'Genre': '발라드',
#   'like': '170,802'},
#  41: {'title': '밤하늘의 별을(2020)',
#   'artist': '경서',
#   'album_name': '밤하늘의 별을(2020)',
#   'Genre': '발라드',
#   'like': '177,237'},
#  42: {'title': '라일락',
#   'artist': '아이유',
#   'album_name': "IU 5th Album 'LILAC'",
#   'Genre': '댄스',
#   'like': '227,949'},
#  43: {'title': '고백',
#   'artist': '멜로망스',
#   'album_name': "세 번째 '고백'",
#   'Genre': '발라드, 인디음악',
#   'like': '63,190'},
#  44: {'title': '그게 더 편할 것 같아 (N번째 연애 X 멜로망스)',
#   'artist': '멜로망스',
#   'album_name': '그게 더 편할 것 같아 (N번째 연애 X 멜로망스)',
#   'Genre': '발라드',
#   'like': '21,127'},
#  45: {'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#   'artist': 'AKMU (악뮤)',
#   'album_name': '항해',
#   'Genre': '발라드',
#   'like': '371,894'},
#  46: {'title': '찰나가 영원이 될 때 (The Eternal Moment)',
#   'artist': '마크툽 (MAKTUB)',
#   'album_name': 'Red Moon : Beyond The Light',
#   'Genre': 'R&B/Soul, 인디음악',
#   'like': '41,786'},
#  47: {'title': '사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)',
#   'artist': '호미들',
#   'album_name': '사이렌 Remix',
#   'Genre': '랩/힙합',
#   'like': '127,105'},
#  48: {'title': '이제 나만 믿어요',
#   'artist': '임영웅',
#   'album_name': '내일은 미스터트롯 우승자 특전곡',
#   'Genre': '성인가요',
#   'like': '145,254'},
#  49: {'title': '너와 나의 Memories',
#   'artist': '염따',
#   'album_name': '쇼미더머니 10 Episode 1',
#   'Genre': '랩/힙합',
#   'like': '35,830'},
#  50: {'title': '시간을 거슬러 (낮에 뜨는 달 X 케이윌)',
#   'artist': '케이윌',
#   'album_name': '시간을 거슬러 (낮에 뜨는 달 X 케이윌)',
#   'Genre': '발라드',
#   'like': '61,884'},
#  51: {'title': "롤린 (Rollin')",
#   'artist': '브레이브걸스',
#   'album_name': "Rollin'",
#   'Genre': '댄스',
#   'like': '290,269'},
#  52: {'title': '밝게 빛나는 별이 되어 비춰줄게',
#   'artist': '송이한',
#   'album_name': '밝게 빛나는 별이 되어 비춰줄게',
#   'Genre': 'R&B/Soul',
#   'like': '109,089'},
#  53: {'title': '추억은 만남보다 이별에 남아',
#   'artist': '정동하',
#   'album_name': '추억은 만남보다 이별에 남아',
#   'Genre': '발라드',
#   'like': '74,934'},
#  54: {'title': '모든 날, 모든 순간 (Every day, Every Moment)',
#   'artist': '폴킴',
#   'album_name': "'키스 먼저 할까요?' OST Part.3",
#   'Genre': '발라드, 국내드라마',
#   'like': '383,978'},
#  55: {'title': '내 손을 잡아',
#   'artist': '아이유',
#   'album_name': '최고의 사랑 OST Part.4',
#   'Genre': '발라드, 국내드라마',
#   'like': '178,527'},
#  56: {'title': '좋아좋아',
#   'artist': '조정석',
#   'album_name': '슬기로운 의사생활 시즌2 OST Part 5',
#   'Genre': '발라드, 국내드라마',
#   'like': '82,227'},
#  57: {'title': '비가 오는 날엔 (2021)',
#   'artist': '헤이즈 (Heize)',
#   'album_name': '비가 오는 날엔 (2021)',
#   'Genre': '발라드, 국내드라마',
#   'like': '61,963'},
#  58: {'title': 'DUMB DUMB',
#   'artist': '전소미',
#   'album_name': 'DUMB DUMB',
#   'Genre': '댄스',
#   'like': '85,389'},
#  59: {'title': 'Dun Dun Dance',
#   'artist': '오마이걸 (OH MY GIRL)',
#   'album_name': 'Dear OHMYGIRL',
#   'Genre': '댄스',
#   'like': '150,231'},
#  60: {'title': 'Blueming',
#   'artist': '아이유',
#   'album_name': 'Love poem',
#   'Genre': '록/메탈',
#   'like': '326,591'},
#  61: {'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)',
#   'artist': '마크툽 (MAKTUB)',
#   'album_name': 'Red Moon : To You My Light',
#   'Genre': 'R&B/Soul, 인디음악',
#   'like': '253,873'},
#  62: {'title': 'Off My Face',
#   'artist': 'Justin Bieber',
#   'album_name': 'Justice (The Complete Edition)',
#   'Genre': 'POP',
#   'like': '98,875'},
#  63: {'title': '흰눈',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'album_name': '흰눈',
#   'Genre': '발라드',
#   'like': '20,992'},
#  64: {'title': '비와 당신',
#   'artist': '이무진',
#   'album_name': '슬기로운 의사생활 시즌2 OST Part 1',
#   'Genre': '록/메탈, 국내드라마',
#   'like': '97,316'},
#  65: {'title': '08베이식 (Feat. 염따, punchnello)',
#   'artist': '베이식 (Basick)',
#   'album_name': '쇼미더머니 10 Semi Final',
#   'Genre': '랩/힙합',
#   'like': '25,647'},
#  66: {'title': '나 그댈위해 시 한편을 쓰겠어',
#   'artist': '케이시 (Kassy)',
#   'album_name': '옛이야기',
#   'Genre': '발라드',
#   'like': '28,002'},
#  67: {'title': 'Queendom',
#   'artist': 'Red Velvet (레드벨벳)',
#   'album_name': 'Queendom - The 6th Mini Album',
#   'Genre': '댄스',
#   'like': '106,241'},
#  68: {'title': 'SCIENTIST',
#   'artist': 'TWICE (트와이스)',
#   'album_name': 'Formula of Love: O+T=<3',
#   'Genre': '댄스',
#   'like': '31,568'},
#  69: {'title': '멜로디',
#   'artist': 'ASH ISLAND',
#   'album_name': '멜로디',
#   'Genre': '랩/힙합',
#   'like': '122,538'},
#  70: {'title': '취기를 빌려 (취향저격 그녀 X 산들)',
#   'artist': '산들',
#   'album_name': '취기를 빌려 (취향저격 그녀 X 산들)',
#   'Genre': '발라드',
#   'like': '207,723'},
#  71: {'title': '그날에 나는 맘이 편했을까',
#   'artist': '이예준',
#   'album_name': '그날에 나는 맘이 편했을까',
#   'Genre': '발라드',
#   'like': '73,622'},
#  72: {'title': 'TROUBLE (Prod. Slom)',
#   'artist': 'Don Mills',
#   'album_name': '쇼미더머니 10 Episode 1',
#   'Genre': '랩/힙합',
#   'like': '35,957'},
#  73: {'title': '그대라는 사치',
#   'artist': '임영웅',
#   'album_name': '사랑의 콜센타 PART62',
#   'Genre': '발라드',
#   'like': '35,661'},
#  74: {'title': 'ASAP',
#   'artist': 'STAYC(스테이씨)',
#   'album_name': 'STAYDOM',
#   'Genre': '댄스',
#   'like': '136,021'},
#  75: {'title': 'Reset (Feat. 개코, Kid Milli) (Prod. 코드 쿤스트)',
#   'artist': 'SINCE',
#   'album_name': '쇼미더머니 10 Episode 3',
#   'Genre': '랩/힙합',
#   'like': '25,559'},
#  76: {'title': '작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)',
#   'artist': '방탄소년단',
#   'album_name': 'MAP OF THE SOUL : PERSONA',
#   'Genre': '댄스',
#   'like': '431,371'},
#  77: {'title': '봄날',
#   'artist': '방탄소년단',
#   'album_name': 'YOU NEVER WALK ALONE',
#   'Genre': '랩/힙합',
#   'like': '554,589'},
#  78: {'title': '다음생이 있다면 당신을 만나서 다시 사랑할래요',
#   'artist': '임재현',
#   'album_name': '다음생이 있다면 당신을 만나서 다시 사랑할래요',
#   'Genre': '발라드',
#   'like': '17,595'},
#  79: {'title': '다시 사랑한다면 (김필 Ver.)',
#   'artist': '임영웅',
#   'album_name': '사랑의 콜센타 PART56',
#   'Genre': '성인가요',
#   'like': '39,343'},
#  80: {'title': 'Savage Love (Laxed - Siren Beat) (BTS Remix)',
#   'artist': 'Jawsh 685',
#   'album_name': 'Savage Love (Laxed - Siren Beat) [BTS Remix]',
#   'Genre': 'POP',
#   'like': '191,886'},
#  81: {'title': '에잇(Prod.&Feat. SUGA of BTS)',
#   'artist': '아이유',
#   'album_name': '에잇',
#   'Genre': '록/메탈',
#   'like': '373,089'},
#  82: {'title': '탕!♡',
#   'artist': 'MINO (송민호)',
#   'album_name': '"TO INFINITY."',
#   'Genre': '랩/힙합',
#   'like': '30,358'},
#  83: {'title': '잊었니',
#   'artist': '임영웅',
#   'album_name': '사랑의 콜센타 PART60',
#   'Genre': '성인가요',
#   'like': '34,667'},
#  84: {'title': 'Lovesick Girls',
#   'artist': 'BLACKPINK',
#   'album_name': 'THE ALBUM',
#   'Genre': '댄스',
#   'like': '208,548'},
#  85: {'title': '가을 우체국 앞에서',
#   'artist': '김대명',
#   'album_name': '슬기로운 의사생활 시즌2 OST Part 2',
#   'Genre': '발라드, 국내드라마',
#   'like': '56,775'},
#  86: {'title': '별빛 같은 나의 사랑아',
#   'artist': '임영웅',
#   'album_name': '별빛 같은 나의 사랑아',
#   'Genre': '성인가요',
#   'like': '68,966'},
#  87: {'title': '하루만 더',
#   'artist': '빅마마',
#   'album_name': '하루만 더',
#   'Genre': '발라드',
#   'like': '54,877'},
#  88: {'title': '취중고백',
#   'artist': '김민석 (멜로망스)',
#   'album_name': '취중고백',
#   'Genre': '발라드',
#   'like': '33,111'},
#  89: {'title': 'Life Goes On',
#   'artist': '방탄소년단',
#   'album_name': 'BE',
#   'Genre': '랩/힙합',
#   'like': '232,409'},
#  90: {'title': '첫 눈',
#   'artist': 'EXO',
#   'album_name': "겨울 스페셜 앨범 '12월의 기적 (Miracles In December)'",
#   'Genre': '발라드',
#   'like': '180,567'},
#  91: {'title': 'HERO',
#   'artist': '임영웅',
#   'album_name': 'HERO',
#   'Genre': '성인가요',
#   'like': '69,099'},
#  92: {'title': 'METEOR',
#   'artist': '창모 (CHANGMO)',
#   'album_name': 'Boyhood',
#   'Genre': '랩/힙합',
#   'like': '277,217'},
#  93: {'title': '끝사랑',
#   'artist': '임영웅',
#   'album_name': '사랑의 콜센타 PART61',
#   'Genre': '성인가요',
#   'like': '32,514'},
#  94: {'title': '바래 (Feat. 정인) (Prod. TOIL)',
#   'artist': '쿤타',
#   'album_name': '쇼미더머니 10 Semi Final',
#   'Genre': '랩/힙합',
#   'like': '17,679'},
#  95: {'title': 'UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)',
#   'artist': 'SINCE',
#   'album_name': '쇼미더머니 10 Final',
#   'Genre': '랩/힙합',
#   'like': '14,875'},
#  96: {'title': '잠이 오질 않네요',
#   'artist': '장범준',
#   'album_name': '잠이 오질 않네요',
#   'Genre': '발라드',
#   'like': '153,710'},
#  97: {'title': '오래된 노래',
#   'artist': '스탠딩 에그',
#   'album_name': '오래된 노래',
#   'Genre': '인디음악, 포크/블루스',
#   'like': '241,001'},
#  98: {'title': '밤새 서로 미루다',
#   'artist': '존박',
#   'album_name': '밤새 서로 미루다',
#   'Genre': '발라드',
#   'like': '15,851'},
#  99: {'title': 'Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afrojack)',
#   'artist': 'David Guetta',
#   'album_name': 'Listen',
#   'Genre': '일렉트로니카',
#   'like': '59,904'}}

# %%
#데이터프레임 만들기
df = pd.DataFrame.from_dict(dict, 'index')
df.head()
# Out:
#                                             title            artist  \
# 0          회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)          sokodomo
# 1                   리무진 (Feat. MINO) (Prod. GRAY)         BE'O (비오)
# 2  만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)      베이식 (Basick)
# 3                  불협화음 (Feat. AKMU) (Prod. GRAY)  Mudd the student
# 4                 Counting Stars (Feat. Beenzino)         BE'O (비오)
#
#             album_name Genre     like
# 0   쇼미더머니 10 Episode 2  랩/힙합  175,093
# 1   쇼미더머니 10 Episode 3  랩/힙합  153,472
# 2   쇼미더머니 10 Episode 3  랩/힙합   99,407
# 3  쇼미더머니 10 Semi Final  랩/힙합   68,537
# 4       Counting Stars  랩/힙합  137,990

# %%
df['Genre']=df['New_Genre']

# %%
df
# Out:
#                                                 title            artist  \
# 0              회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)          sokodomo
# 1                       리무진 (Feat. MINO) (Prod. GRAY)         BE'O (비오)
# 2      만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)      베이식 (Basick)
# 3                      불협화음 (Feat. AKMU) (Prod. GRAY)  Mudd the student
# 4                     Counting Stars (Feat. Beenzino)         BE'O (비오)
# ..                                                ...               ...
# 95                UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)             SINCE
# 96                                          잠이 오질 않네요               장범준
# 97                                             오래된 노래            스탠딩 에그
# 98                                          밤새 서로 미루다                존박
# 99  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...      David Guetta
#
#              album_name         Genre     like     New_Genre
# 0    쇼미더머니 10 Episode 2          랩/힙합  175,093          랩/힙합
# 1    쇼미더머니 10 Episode 3          랩/힙합  153,472          랩/힙합
# 2    쇼미더머니 10 Episode 3          랩/힙합   99,407          랩/힙합
# 3   쇼미더머니 10 Semi Final          랩/힙합   68,537          랩/힙합
# 4        Counting Stars          랩/힙합  137,990          랩/힙합
# ..                  ...           ...      ...           ...
# 95       쇼미더머니 10 Final          랩/힙합   14,875          랩/힙합
# 96            잠이 오질 않네요           발라드  153,710           발라드
# 97               오래된 노래  인디음악, 포크/블루스  241,001  인디음악, 포크/블루스
# 98            밤새 서로 미루다           발라드   15,851           발라드
# 99               Listen        일렉트로니카   59,904        일렉트로니카
#
# [100 rows x 6 columns]

# %%
#'발라드, 국내드라마','발라드,인디음악' 값을 '발라드'로 변경
df.loc[(df.New_Genre=='발라드, 인디음악'),'New_Genre']='발라드'

# %%
#'발라드, 국내드라마','록/메탈, 국내드라마' 값을 'OST'로 변경
df.loc[(df.New_Genre=='발라드, 국내드라마'),'New_Genre']='OST'
df.loc[(df.New_Genre=='록/메탈, 국내드라마'),'New_Genre']='OST'

# %%
#R&B/Soul, 인디음악' 값을 'R&B/Soul'으로 변경
df.loc[(df.New_Genre=='R&B/Soul, 인디음악'),'New_Genre']='R&B/Soul'

# %%
df[0:50]
# Out:
#                                              title               artist  \
# 0           회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)             sokodomo
# 1                    리무진 (Feat. MINO) (Prod. GRAY)            BE'O (비오)
# 2   만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)         베이식 (Basick)
# 3                   불협화음 (Feat. AKMU) (Prod. GRAY)     Mudd the student
# 4                  Counting Stars (Feat. Beenzino)            BE'O (비오)
# 5                                  strawberry moon                  아이유
# 6                                           ELEVEN            IVE (아이브)
# 7                     쉬어 (Feat. MINO) (Prod. GRAY)  아넌딜라이트(Anandelight)
# 8                                        사랑은 늘 도망가                  임영웅
# 9                                    다정히 내 이름을 부르면                 경서예지
# 10                          Wake Up (Prod. 코드 쿤스트)                   개코
# 11                                             신호등                  이무진
# 12                 All I Want for Christmas Is You         Mariah Carey
# 13                                          Savage                aespa
# 14                                            STAY        The Kid LAROI
# 15                                   Santa Tell Me        Ariana Grande
# 16                                눈이 오잖아(Feat.헤이즈)                  이무진
# 17         네가 없는 밤 (Feat. ASH ISLAND) (Prod. GRAY)            BE'O (비오)
# 18                                      Next Level                aespa
# 19               MBTI (Feat. 쿠기 & 로꼬) (Prod. GRAY)            BE'O (비오)
# 20                                          너를 생각해         주시크 (Joosiq)
# 21                                  OHAYO MY NIGHT          디핵 (D-Hack)
# 22                   매일 크리스마스 (Everyday Christmas)                  다비치
# 23                                   낙하 (with 아이유)            AKMU (악뮤)
# 24                                              문득            BE'O (비오)
# 25                                          바라만 본다        MSG워너비(M.O.M)
# 26                                          Butter                방탄소년단
# 27                                     My Universe             Coldplay
# 28                                         Snowman                  Sia
# 29                             Permission to Dance                방탄소년단
# 30                 미리 메리 크리스마스 (Feat. 천둥 Of MBLAQ)                  아이유
# 31    호우주의 (Feat. 개코, 넉살 (Nucksal)) (Prod. 코드 쿤스트)                  조광일
# 32                                           헤픈 우연          헤이즈 (Heize)
# 33                                         Weekend         태연 (TAEYEON)
# 34                                        Dynamite                방탄소년단
# 35          깐부 (Feat. 염따, ASH ISLAND) (Prod. TOIL)                   쿤타
# 36                                       Celebrity                  아이유
# 37          Peaches (Feat. Daniel Caesar & Giveon)        Justin Bieber
# 38                                      Bad Habits           Ed Sheeran
# 39                                  Last Christmas        Ariana Grande
# 40                                         크리스마스니까                  성시경
# 41                                   밤하늘의 별을(2020)                   경서
# 42                                             라일락                  아이유
# 43                                              고백                 멜로망스
# 44                    그게 더 편할 것 같아 (N번째 연애 X 멜로망스)                 멜로망스
# 45                       어떻게 이별까지 사랑하겠어, 널 사랑하는 거지            AKMU (악뮤)
# 46                찰나가 영원이 될 때 (The Eternal Moment)         마크툽 (MAKTUB)
# 47   사이렌 Remix (Feat. UNEDUCATED KID, Paul Blanco)                  호미들
# 48                                       이제 나만 믿어요                  임영웅
# 49                                  너와 나의 Memories                   염따
#
#                                         album_name           Genre     like  \
# 0                               쇼미더머니 10 Episode 2            랩/힙합  175,093
# 1                               쇼미더머니 10 Episode 3            랩/힙합  153,472
# 2                               쇼미더머니 10 Episode 3            랩/힙합   99,407
# 3                              쇼미더머니 10 Semi Final            랩/힙합   68,537
# 4                                   Counting Stars            랩/힙합  137,990
# 5                                  strawberry moon            록/메탈  174,809
# 6                                           ELEVEN              댄스   87,906
# 7                               쇼미더머니 10 Episode 1            랩/힙합   92,461
# 8                               신사와 아가씨 OST Part.2      발라드, 국내드라마  107,793
# 9                       다정히 내 이름을 부르면 (경서예지 x 전건호)             발라드  101,939
# 10                              쇼미더머니 10 Episode 1            랩/힙합   74,690
# 11                                             신호등            록/메탈  252,228
# 12    Merry Christmas (Deluxe Anniversary Edition)        R&B/Soul  204,169
# 13                     Savage - The 1st Mini Album              댄스  134,854
# 14                                            Stay             POP  197,757
# 15                                   Santa Tell Me             POP  216,160
# 16                                눈이 오잖아(Feat.헤이즈)             발라드   47,674
# 17                                  쇼미더머니 10 Final            랩/힙합   49,227
# 18                                      Next Level              댄스  231,647
# 19                             쇼미더머니 10 Semi Final            랩/힙합   41,915
# 20                                          너를 생각해  R&B/Soul, 인디음악   89,960
# 21                                  OHAYO MY NIGHT            랩/힙합  169,206
# 22                   매일 크리스마스 (Everyday Christmas)              댄스   23,812
# 23                                    NEXT EPISODE            록/메탈  162,197
# 24                                         Bipolar            랩/힙합   72,624
# 25                                       MSG워너비 1집             발라드  167,502
# 26                                          Butter              댄스  261,800
# 27                                     My Universe             POP  144,676
# 28  Everyday Is Christmas (Snowman Deluxe Edition)             POP  200,777
# 29                    Butter / Permission to Dance              댄스  193,226
# 30                                            Real              댄스  166,979
# 31                             쇼미더머니 10 Semi Final            랩/힙합   32,994
# 32                                          HAPPEN        R&B/Soul  166,377
# 33                                         Weekend              댄스  156,219
# 34                      Dynamite (DayTime Version)              댄스  428,118
# 35                              쇼미더머니 10 Episode 3            랩/힙합   30,833
# 36                            IU 5th Album 'LILAC'              댄스  310,368
# 37                  Justice (The Complete Edition)             POP  210,177
# 38                                               =             POP   96,811
# 39                                Christmas Kisses             POP   43,278
# 40              Jelly Christmas 2012 HEART PROJECT             발라드  170,802
# 41                                   밤하늘의 별을(2020)             발라드  177,237
# 42                            IU 5th Album 'LILAC'              댄스  227,949
# 43                                       세 번째 '고백'       발라드, 인디음악   63,190
# 44                    그게 더 편할 것 같아 (N번째 연애 X 멜로망스)             발라드   21,127
# 45                                              항해             발라드  371,894
# 46                     Red Moon : Beyond The Light  R&B/Soul, 인디음악   41,786
# 47                                       사이렌 Remix            랩/힙합  127,105
# 48                               내일은 미스터트롯 우승자 특전곡            성인가요  145,254
# 49                              쇼미더머니 10 Episode 1            랩/힙합   35,830
#
#    New_Genre
# 0       랩/힙합
# 1       랩/힙합
# 2       랩/힙합
# 3       랩/힙합
# 4       랩/힙합
# 5       록/메탈
# 6         댄스
# 7       랩/힙합
# 8        OST
# 9        발라드
# 10      랩/힙합
# 11      록/메탈
# 12  R&B/Soul
# 13        댄스
# 14       POP
# 15       POP
# 16       발라드
# 17      랩/힙합
# 18        댄스
# 19      랩/힙합
# 20  R&B/Soul
# 21      랩/힙합
# 22        댄스
# 23      록/메탈
# 24      랩/힙합
# 25       발라드
# 26        댄스
# 27       POP
# 28       POP
# 29        댄스
# 30        댄스
# 31      랩/힙합
# 32  R&B/Soul
# 33        댄스
# 34        댄스
# 35      랩/힙합
# 36        댄스
# 37       POP
# 38       POP
# 39       POP
# 40       발라드
# 41       발라드
# 42        댄스
# 43       발라드
# 44       발라드
# 45       발라드
# 46  R&B/Soul
# 47      랩/힙합
# 48      성인가요
# 49      랩/힙합

# %%
df[50:100]
# Out:
#                                                 title               artist  \
# 50                            시간을 거슬러 (낮에 뜨는 달 X 케이윌)                  케이윌
# 51                                       롤린 (Rollin')               브레이브걸스
# 52                                  밝게 빛나는 별이 되어 비춰줄게                  송이한
# 53                                    추억은 만남보다 이별에 남아                  정동하
# 54              모든 날, 모든 순간 (Every day, Every Moment)                   폴킴
# 55                                            내 손을 잡아                  아이유
# 56                                               좋아좋아                  조정석
# 57                                    비가 오는 날엔 (2021)          헤이즈 (Heize)
# 58                                          DUMB DUMB                  전소미
# 59                                      Dun Dun Dance    오마이걸 (OH MY GIRL)
# 60                                           Blueming                  아이유
# 61           오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)         마크툽 (MAKTUB)
# 62                                        Off My Face        Justin Bieber
# 63                                                 흰눈  먼데이 키즈 (Monday Kiz)
# 64                                              비와 당신                  이무진
# 65                       08베이식 (Feat. 염따, punchnello)         베이식 (Basick)
# 66                                   나 그댈위해 시 한편을 쓰겠어          케이시 (Kassy)
# 67                                           Queendom    Red Velvet (레드벨벳)
# 68                                          SCIENTIST         TWICE (트와이스)
# 69                                                멜로디           ASH ISLAND
# 70                              취기를 빌려 (취향저격 그녀 X 산들)                   산들
# 71                                     그날에 나는 맘이 편했을까                  이예준
# 72                               TROUBLE (Prod. Slom)            Don Mills
# 73                                            그대라는 사치                  임영웅
# 74                                               ASAP          STAYC(스테이씨)
# 75         Reset (Feat. 개코, Kid Milli) (Prod. 코드 쿤스트)                SINCE
# 76          작은 것들을 위한 시 (Boy With Luv) (Feat. Halsey)                방탄소년단
# 77                                                 봄날                방탄소년단
# 78                          다음생이 있다면 당신을 만나서 다시 사랑할래요                  임재현
# 79                                 다시 사랑한다면 (김필 Ver.)                  임영웅
# 80       Savage Love (Laxed - Siren Beat) (BTS Remix)            Jawsh 685
# 81                        에잇(Prod.&Feat. SUGA of BTS)                  아이유
# 82                                                탕!♡           MINO (송민호)
# 83                                                잊었니                  임영웅
# 84                                     Lovesick Girls            BLACKPINK
# 85                                         가을 우체국 앞에서                  김대명
# 86                                       별빛 같은 나의 사랑아                  임영웅
# 87                                              하루만 더                  빅마마
# 88                                               취중고백           김민석 (멜로망스)
# 89                                       Life Goes On                방탄소년단
# 90                                                첫 눈                  EXO
# 91                                               HERO                  임영웅
# 92                                             METEOR         창모 (CHANGMO)
# 93                                                끝사랑                  임영웅
# 94                         바래 (Feat. 정인) (Prod. TOIL)                   쿤타
# 95                UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)                SINCE
# 96                                          잠이 오질 않네요                  장범준
# 97                                             오래된 노래               스탠딩 에그
# 98                                          밤새 서로 미루다                   존박
# 99  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...         David Guetta
#
#                                       album_name           Genre     like  \
# 50                       시간을 거슬러 (낮에 뜨는 달 X 케이윌)             발라드   61,884
# 51                                       Rollin'              댄스  290,269
# 52                             밝게 빛나는 별이 되어 비춰줄게        R&B/Soul  109,089
# 53                               추억은 만남보다 이별에 남아             발라드   74,934
# 54                       '키스 먼저 할까요?' OST Part.3      발라드, 국내드라마  383,978
# 55                             최고의 사랑 OST Part.4      발라드, 국내드라마  178,527
# 56                      슬기로운 의사생활 시즌2 OST Part 5      발라드, 국내드라마   82,227
# 57                               비가 오는 날엔 (2021)      발라드, 국내드라마   61,963
# 58                                     DUMB DUMB              댄스   85,389
# 59                                 Dear OHMYGIRL              댄스  150,231
# 60                                     Love poem            록/메탈  326,591
# 61                    Red Moon : To You My Light  R&B/Soul, 인디음악  253,873
# 62                Justice (The Complete Edition)             POP   98,875
# 63                                            흰눈             발라드   20,992
# 64                      슬기로운 의사생활 시즌2 OST Part 1     록/메탈, 국내드라마   97,316
# 65                           쇼미더머니 10 Semi Final            랩/힙합   25,647
# 66                                          옛이야기             발라드   28,002
# 67                 Queendom - The 6th Mini Album              댄스  106,241
# 68                       Formula of Love: O+T=<3              댄스   31,568
# 69                                           멜로디            랩/힙합  122,538
# 70                         취기를 빌려 (취향저격 그녀 X 산들)             발라드  207,723
# 71                                그날에 나는 맘이 편했을까             발라드   73,622
# 72                            쇼미더머니 10 Episode 1            랩/힙합   35,957
# 73                                사랑의 콜센타 PART62             발라드   35,661
# 74                                       STAYDOM              댄스  136,021
# 75                            쇼미더머니 10 Episode 3            랩/힙합   25,559
# 76                     MAP OF THE SOUL : PERSONA              댄스  431,371
# 77                          YOU NEVER WALK ALONE            랩/힙합  554,589
# 78                     다음생이 있다면 당신을 만나서 다시 사랑할래요             발라드   17,595
# 79                                사랑의 콜센타 PART56            성인가요   39,343
# 80  Savage Love (Laxed - Siren Beat) [BTS Remix]             POP  191,886
# 81                                            에잇            록/메탈  373,089
# 82                                "TO INFINITY."            랩/힙합   30,358
# 83                                사랑의 콜센타 PART60            성인가요   34,667
# 84                                     THE ALBUM              댄스  208,548
# 85                      슬기로운 의사생활 시즌2 OST Part 2      발라드, 국내드라마   56,775
# 86                                  별빛 같은 나의 사랑아            성인가요   68,966
# 87                                         하루만 더             발라드   54,877
# 88                                          취중고백             발라드   33,111
# 89                                            BE            랩/힙합  232,409
# 90    겨울 스페셜 앨범 '12월의 기적 (Miracles In December)'             발라드  180,567
# 91                                          HERO            성인가요   69,099
# 92                                       Boyhood            랩/힙합  277,217
# 93                                사랑의 콜센타 PART61            성인가요   32,514
# 94                           쇼미더머니 10 Semi Final            랩/힙합   17,679
# 95                                쇼미더머니 10 Final            랩/힙합   14,875
# 96                                     잠이 오질 않네요             발라드  153,710
# 97                                        오래된 노래    인디음악, 포크/블루스  241,001
# 98                                     밤새 서로 미루다             발라드   15,851
# 99                                        Listen          일렉트로니카   59,904
#
#        New_Genre
# 50           발라드
# 51            댄스
# 52      R&B/Soul
# 53           발라드
# 54           OST
# 55           OST
# 56           OST
# 57           OST
# 58            댄스
# 59            댄스
# 60          록/메탈
# 61      R&B/Soul
# 62           POP
# 63           발라드
# 64           OST
# 65          랩/힙합
# 66           발라드
# 67            댄스
# 68            댄스
# 69          랩/힙합
# 70           발라드
# 71           발라드
# 72          랩/힙합
# 73           발라드
# 74            댄스
# 75          랩/힙합
# 76            댄스
# 77          랩/힙합
# 78           발라드
# 79          성인가요
# 80           POP
# 81          록/메탈
# 82          랩/힙합
# 83          성인가요
# 84            댄스
# 85           OST
# 86          성인가요
# 87           발라드
# 88           발라드
# 89          랩/힙합
# 90           발라드
# 91          성인가요
# 92          랩/힙합
# 93          성인가요
# 94          랩/힙합
# 95          랩/힙합
# 96           발라드
# 97  인디음악, 포크/블루스
# 98           발라드
# 99        일렉트로니카

# %%
#저장하기
df.to_csv("melon_2021_12_Chart_final.csv")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/oseunghui/Desktop'

# %%
#csv 불러오기
genre_2021_12 = pd.read_csv("melon_2021_12_Chart_final.csv")

# %%
genre_2021_12['New_Genre'].value_counts()
# Out:
# 랩/힙합            25
# 발라드             21
# 댄스              19
# POP              9
# OST              7
# R&B/Soul         6
# 성인가요             6
# 록/메탈             5
# 인디음악, 포크/블루스     1
# 일렉트로니카           1
# Name: New_Genre, dtype: int64

# %%
# 튜플 형태로 라벨 지정
labels = '랩/힙합', '발라드','댄스','POP','OST','R&B/Soul','성인가요','록/메탈','일렉트로니카','인디음악, 포크/블루스'
labels
# Out:
# ('랩/힙합',
#  '발라드',
#  '댄스',
#  'POP',
#  'OST',
#  'R&B/Soul',
#  '성인가요',
#  '록/메탈',
#  '일렉트로니카',
#  '인디음악, 포크/블루스')

# %%
genre_2021_12.columns
# Out:
# Index(['title', 'artist', 'album_name', 'Genre', 'like', 'New_Genre'], dtype='object')

# %%
#'Unnamed:0' 칼럼 제거
genre_2021_12.drop(['Unnamed: 0'], axis = 1, inplace = True)

# %%
genre_2021_12
# Out:
#                                                 title            artist  \
# 0              회전목마 (Feat. Zion.T, 원슈타인) (Prod. Slom)          sokodomo
# 1                       리무진 (Feat. MINO) (Prod. GRAY)         BE'O (비오)
# 2      만남은 쉽고 이별은 어려워 (Feat. Leellamarz) (Prod. TOIL)      베이식 (Basick)
# 3                      불협화음 (Feat. AKMU) (Prod. GRAY)  Mudd the student
# 4                     Counting Stars (Feat. Beenzino)         BE'O (비오)
# ..                                                ...               ...
# 95                UP해 (Feat. 박재범, 우원재) (Prod. 코드 쿤스트)             SINCE
# 96                                          잠이 오질 않네요               장범준
# 97                                             오래된 노래            스탠딩 에그
# 98                                          밤새 서로 미루다                존박
# 99  Hey Mama (Feat. Nicki Minaj, Bebe Rexha & Afro...      David Guetta
#
#              album_name         Genre     like     New_Genre
# 0    쇼미더머니 10 Episode 2          랩/힙합  175,093          랩/힙합
# 1    쇼미더머니 10 Episode 3          랩/힙합  153,472          랩/힙합
# 2    쇼미더머니 10 Episode 3          랩/힙합   99,407          랩/힙합
# 3   쇼미더머니 10 Semi Final          랩/힙합   68,537          랩/힙합
# 4        Counting Stars          랩/힙합  137,990          랩/힙합
# ..                  ...           ...      ...           ...
# 95       쇼미더머니 10 Final          랩/힙합   14,875          랩/힙합
# 96            잠이 오질 않네요           발라드  153,710           발라드
# 97               오래된 노래  인디음악, 포크/블루스  241,001  인디음악, 포크/블루스
# 98            밤새 서로 미루다           발라드   15,851           발라드
# 99               Listen        일렉트로니카   59,904        일렉트로니카
#
# [100 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

plt.rc('font', family='AppleGothic')

# %%
# 색(colors) 정하기, 차트 입체적으로(explode) 보이게
colors=['lightsteelblue','mistyrose','powderblue','bisque','thistle',\
        'lavender','lightgray','lightcyan','linen','pink']
explode=(0.05,0.05,0.05,0.05,0.07,0.08,0.1,0.1,0.1,0.1)

# %%
plt.figure(figsize=(15,15))

# pie chart 만들기(차트 띄우기, labels 달기, 각 조정, 시계방향순서, 그림자, 값 소숫점 표시)
plt.pie(genre_2021_12['New_Genre'].value_counts(), explode=explode, labels=None, startangle=90,\
        counterclock=False, shadow=True, autopct='%.1f',colors=colors)

# 라벨, 타이틀 달기
plt.title('<2021년 12월 월간 TOP100 장르별 비율>', fontsize=25, color='gray')

# 레전드 달기
plt.legend(labels,loc='lower left')

plt.show()
